# %% [markdown]
# Problem Statement:
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# -- Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, Complete Games and Errors
#
# -- Output: Number of predicted wins (W)
#
# To understand the columns meaning, follow the link given below to understand the baseball statistics: https://en.wikipedia.org/wiki/Baseball_statistics

# %%
import pandas as pd
import numpy as np

# %%
pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv')
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
Data=pd.read_csv("D:baseball.csv")

# %%
type(Data)
# Out:
# pandas.core.frame.DataFrame

# %%
Data
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# ...

# %%
Data.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
Data.tail()
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 25  92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26  84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27  79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28  74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29  68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV   E
# 25   21  47  75
# 26   18  41  78
# 27   12  44  86
# 28    6  41  92
# 29    4  36  95

# %%
Data.sample()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO  SB   RA   ER   ERA  CG  SHO  \
# 8  80  644  5485  1383  278  32  167  436  1310  87  642  604  3.74   1   12
#
#    SV   E
# 8  60  95

# %%
# indexes at axis=1
type(Data.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
Data.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
#  Null values

# %%
Data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# imputation

# %% [markdown]
# - categorical column ==> mode
# - continous column== > mean/median

# %%
# Data.fillna()

# %%
Data.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# EDA

# %% [markdown]
# Scatterplot:

# %%
import seaborn as sns

# %%
# sns.scatterplot()

# %%
sns.scatterplot(x="R",y="AB",data=Data)
# Out:
# <AxesSubplot:xlabel='R', ylabel='AB'>

# %%
sns.scatterplot(x="R",y="2B",data=Data)
# Out:
# <AxesSubplot:xlabel='R', ylabel='2B'>

# %%
sns.scatterplot(x="R",y="3B",data=Data)
# Out:
# <AxesSubplot:xlabel='R', ylabel='3B'>

# %%
sns.scatterplot(x="H",y="AB",data=Data)
# Out:
# <AxesSubplot:xlabel='H', ylabel='AB'>

# %%
sns.scatterplot(x="H",y="2B",data=Data)
# Out:
# <AxesSubplot:xlabel='H', ylabel='2B'>

# %%
sns.scatterplot(x="H",y="3B",data=Data)
# Out:
# <AxesSubplot:xlabel='H', ylabel='3B'>

# %%
sns.scatterplot(x="R",y="SB",data=Data)
# Out:
# <AxesSubplot:xlabel='R', ylabel='SB'>

# %%
sns.scatterplot(x="RA",y="AB",data=Data)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='AB'>

# %%
sns.scatterplot(x="RA",y="2B",data=Data)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='2B'>

# %%
sns.scatterplot(x="RA",y="3B",data=Data)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='3B'>

# %%
sns.scatterplot(x="W",y="AB",data=Data)
# Out:
# <AxesSubplot:xlabel='W', ylabel='AB'>

# %%
sns.scatterplot(x="W",y="2B",data=Data)
# Out:
# <AxesSubplot:xlabel='W', ylabel='2B'>

# %%
sns.scatterplot(x="W",y="3B",data=Data)
# Out:
# <AxesSubplot:xlabel='W', ylabel='3B'>

# %%
sns.scatterplot(x="ER",y="AB",data=Data)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='AB'>

# %%
sns.scatterplot(x="W",y="2B",data=Data)
# Out:
# <AxesSubplot:xlabel='W', ylabel='2B'>

# %%
sns.scatterplot(x="ER",y="3B",data=Data)
# Out:
# <AxesSubplot:xlabel='ER', ylabel='3B'>

# %%
sns.scatterplot(x="ERA",y="AB",data=Data)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='AB'>

# %%
sns.scatterplot(x="ERA",y="2B",data=Data)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='2B'>

# %%
sns.scatterplot(x="ERA",y="3B",data=Data)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='3B'>

# %%
sns.scatterplot(x="SO",y="AB",data=Data)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='AB'>

# %%
sns.scatterplot(x="SO",y="2B",data=Data)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='2B'>

# %%
sns.scatterplot(x="SO",y="3B",data=Data)
# Out:
# <AxesSubplot:xlabel='SO', ylabel='3B'>

# %%
sns.scatterplot(x="SV",y="AB",data=Data)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='AB'>

# %%
sns.scatterplot(x="SV",y="2B",data=Data)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='2B'>

# %%
sns.scatterplot(x="SV",y="3B",data=Data)
# Out:
# <AxesSubplot:xlabel='SV', ylabel='3B'>

# %%
sns.scatterplot(x="HR",y="AB",data=Data)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='AB'>

# %%
sns.scatterplot(x="HR",y="2B",data=Data)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='2B'>

# %%
sns.scatterplot(x="HR",y="3B",data=Data)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='3B'>

# %%
sns.scatterplot(x="SHO",y="AB",data=Data)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='AB'>

# %%
sns.scatterplot(x="SHO",y="2B",data=Data)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='2B'>

# %%
sns.scatterplot(x="SHO",y="3B",data=Data)
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='3B'>

# %%
sns.scatterplot(x="E",y="AB",data=Data)
# Out:
# <AxesSubplot:xlabel='E', ylabel='AB'>

# %%
sns.scatterplot(x="E",y="2B",data=Data)
# Out:
# <AxesSubplot:xlabel='E', ylabel='2B'>

# %%
sns.scatterplot(x="E",y="3B",data=Data)
# Out:
# <AxesSubplot:xlabel='E', ylabel='3B'>

# %%
sns.scatterplot(x="CG",y="AB",data=Data)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='AB'>

# %%
sns.scatterplot(x="CG",y="2B",data=Data)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='2B'>

# %%
sns.scatterplot(x="CG",y="3B",data=Data)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='3B'>

# %%
sns.scatterplot(x="CG",y="ERA",data=Data)
# Out:
# <AxesSubplot:xlabel='CG', ylabel='ERA'>

# %%
import matplotlib.pyplot as plt
sns.pairplot(Data)
plt.savefig('pairplot.png')
plt.show()

# %% [markdown]
# correlation

# %%
Data.corr()
# Out:
#             W         R        AB         H        2B        3B        HR  \
# W    1.000000  0.430751 -0.087947  0.037612  0.427797 -0.251118  0.307407
# R    0.430751  1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# AB  -0.087947  0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# H    0.037612  0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# 2B   0.427797  0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# 3B  -0.251118 -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# HR   0.307407  0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# BB   0.484342  0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# SO   0.111850 -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# SB  -0.157234  0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# RA  -0.812952 -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# ER  -0.809435 -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ...

# %%
Data.corr()['ERA'].sort_values()
# Out:
# W     -0.819600
# SHO   -0.630833
# SV    -0.607005
# BB    -0.459832
# 2B    -0.254854
# SO    -0.180368
# HR    -0.090917
# R     -0.049281
# CG    -0.009856
# E      0.113137
# SB     0.126063
# H      0.231172
# AB     0.255551
# 3B     0.330951
# RA     0.986674
# ER     0.997248
# ERA    1.000000
# Name: ERA, dtype: float64

# %% [markdown]
# CORRELATION USING HEATMAP

# %%
import matplotlib.pyplot as plt
# size of canvas
plt.figure(figsize=(19,19))

sns.heatmap(Data.corr(), annot=True, linewidths=0.5,linecolor="black", fmt= '.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Descriptive statistics

# %%
Data.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(19,19))
sns.heatmap(round (Data.describe()[1:].transpose(),2),linewidth=2,annot=False,fmt="f")
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title("variables summary")
plt.savefig('heatmap.png')
plt.show()

# %%
Data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# Outliers checking:

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
collist=Data.columns.values
ncol=30
nrow=14

# %%
collist
# Out:
# array(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA',
#        'ER', 'ERA', 'CG', 'SHO', 'SV', 'E'], dtype=object)

# %%
len(list(range(0,len(collist))))
# Out:
# 17

# %%
for i in range(0, len(collist)):
    print(collist[i])
    break
# Out:
# W

# %%
Data[collist[0]]
# Out:
# 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64

# %%
plt.figure(figsize=(ncol,3*ncol))
for i in range (0, len(collist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data = Data[collist[i]],color='green',orient='v')
    plt.tight_layout()

# %% [markdown]
#  Skewness:

# %%
Data.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# Normal Distribution Curve:

# %%
sns.distplot(Data["W"])
# Out:
# <AxesSubplot:xlabel='W', ylabel='Density'>

# %%
sns.distplot(Data["R"])
# Out:
# <AxesSubplot:xlabel='R', ylabel='Density'>

# %%
sns.distplot(Data["AB"])
# Out:
# <AxesSubplot:xlabel='AB', ylabel='Density'>

# %%
sns.distplot(Data["ERA"])
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='Density'>

# %%
sns.distplot(Data["H"])
# Out:
# <AxesSubplot:xlabel='H', ylabel='Density'>

# %%
sns.distplot(Data["2B"])
# Out:
# <AxesSubplot:xlabel='2B', ylabel='Density'>

# %%
sns.distplot(Data["3B"])
# Out:
# <AxesSubplot:xlabel='3B', ylabel='Density'>

# %%
sns.distplot(Data["ER"])
# Out:
# <AxesSubplot:xlabel='ER', ylabel='Density'>

# %%
sns.distplot(Data["HR"])
# Out:
# <AxesSubplot:xlabel='HR', ylabel='Density'>

# %%
sns.distplot(Data["CG"])
# Out:
# <AxesSubplot:xlabel='CG', ylabel='Density'>

# %%
sns.distplot(Data["SHO"])
# Out:
# <AxesSubplot:xlabel='SHO', ylabel='Density'>

# %%
sns.distplot(Data["SV"])
# Out:
# <AxesSubplot:xlabel='SV', ylabel='Density'>

# %%
sns.distplot(Data["SO"])
# Out:
# <AxesSubplot:xlabel='SO', ylabel='Density'>

# %%
sns.distplot(Data["SB"])
# Out:
# <AxesSubplot:xlabel='SB', ylabel='Density'>

# %%
sns.distplot(Data["E"])
# Out:
# <AxesSubplot:xlabel='E', ylabel='Density'>

# %%
Data.corr()['W']
# Out:
# W      1.000000
# R      0.430751
# AB    -0.087947
# H      0.037612
# 2B     0.427797
# 3B    -0.251118
# HR     0.307407
# BB     0.484342
# SO     0.111850
# SB    -0.157234
# RA    -0.812952
# ER    -0.809435
# ERA   -0.819600
# CG     0.080533
# SHO    0.471805
# SV     0.666530
# E     -0.089485
# Name: W, dtype: float64

# %%
delete=pd.DataFrame([["0.037612","H","No","Alot"],["0.080533","CG","No","Alot"]],
                   columns=["Correlation with Target","Column Name","Normalised","Outliers"])
delete
# Out:
#   Correlation with Target Column Name Normalised Outliers
# 0                0.037612           H         No     Alot
# 1                0.080533          CG         No     Alot

# %%
Data=Data.drop(["H","CG"],axis=1)

# %%
Data
# Out:
#       W    R    AB   2B  3B   HR   BB    SO   SB   RA   ER   ERA  SHO  SV    E
# 0    95  724  5575  300  42  139  383   973  104  641  601  3.73    8  56   88
# 1    83  696  5467  277  44  156  439  1264   70  700  653  4.07   12  45   86
# 2    81  669  5439  303  29  141  533  1157   86  640  584  3.67   10  38   79
# 3    76  622  5533  260  27  136  404  1231   68  701  643  3.98    9  37  101
# 4    74  689  5605  289  49  151  455  1259   83  803  746  4.64   12  35   86
# 5    93  891  5509  308  17  232  570  1151   88  670  609  3.80   10  34   88
# 6    87  764  5567  272  19  212  554  1227   63  698  652  4.03    4  48   93
# 7    81  713  5485  246  20  217  418  1331   44  693  646  4.05   10  43   77
# 8    80  644  5485  278  32  167  436  1310   87  642  604  3.74   12  60   95
# 9    78  748  5640  294  33  161  478  1148   71  753  694  4.31   10  40   97
# 10   88  751  5511  279  32  172  503  1233  101  733  680  4.24    9  45  119
# ...

# %% [markdown]
# Removing outliers

# %% [markdown]
# Z-Score Technique:

# %%
IQR proximity rule

# %%
np.abs(2)
# Out:
# 2

# %%
np.abs(-2)
# Out:
# 2

# %%
mod of mathematics

# %%
|-2| = -1(-2) = 2
|2| = 1(2) = 2

# %%
from scipy.stats import zscore

# %%
import numpy as np
z=np.abs(zscore(Data))
z.shape
# Out:
# (30, 15)

# %%
type(z)
# Out:
# pandas.core.frame.DataFrame

# %%
# index number
np.where(z>2)
# Out:
# (array([ 0,  5,  5,  8, 11, 14, 15, 15, 15, 15, 16, 17, 17, 19, 22, 23, 25,
#         27, 29, 29, 29], dtype=int64),
#  array([ 7,  1,  5, 13,  5, 14,  9, 10, 11, 13, 14,  7, 12,  8,  3,  5, 12,
#          8,  9, 10, 11], dtype=int64))

# %%
np.abs(zscore(Data))
# Out:
#            W         R        AB        2B        3B        HR        BB  \
# 0   1.365409  0.619078  0.847731  1.420173  1.041193  0.787299  1.534902
# 1   0.197838  0.134432  0.711094  0.127403  1.235809  0.243967  0.536592
# 2   0.003243  0.332906  1.115233  1.588795  0.223808  0.723377  1.139144
# 3   0.483244  1.146419  0.241522  0.828122  0.418423  0.883181  1.160536
# 4   0.677839  0.013270  1.280738  0.801892  1.722347  0.403770  0.251360
# 5   1.170814  3.509647  0.104884  1.869832  1.391501  2.185047  1.798742
# 6   0.587028  1.311430  0.732263  0.153633  1.196885  1.545833  1.513510
# 7   0.003243  0.428681  0.451289  1.615025  1.099578  1.705636  0.910958
# 8   0.094054  0.765626  0.451289  0.183611  0.068115  0.107601  0.590073
# 9   0.288649  1.034489  1.785913  1.082929  0.165423  0.084163  0.158660
# 10  0.684326  1.086415  0.076017  0.239818  0.068115  0.267405  0.604334
# 11  0.489731  0.705622  0.826562  0.183611  0.515731  2.121125  0.301276
# ...

# %%
z.iloc[5]
# Out:
# W      1.170814
# R      3.509647
# AB     0.104884
# 2B     1.869832
# 3B     1.391501
# HR     2.185047
# BB     1.798742
# SO     0.952796
# SB     0.200609
# RA     0.257184
# ER     0.389104
# ERA    0.350165
# SHO    0.320914
# SV     1.171848
# E      0.461470
# Name: 5, dtype: float64

# %%
len(np.where(z>2)[0])
# Out:
# 21

# %%
len(np.where(z>2)[0])
# Out:
# 21

# %%
Data_new=Data[(z<2).all(axis=1)]

# %%
numpy
row wise - axis=1
column wise --- axis=0

pands
row wise --- axis=0
column wise --- axis=1

# %%
print("Old Dataframe",Data.shape)
print("New Dataframe",Data_new.shape)
print("total_dropped_rows",Data.shape[0] - Data_new.shape[0])
# Out:
# Old Dataframe (30, 15)
# New Dataframe (16, 15)
# total_dropped_rows 14

# %% [markdown]
# Percentage data loss

# %%
loss_percent=(30-16)/30*100
print(loss_percent,'%')
# Out:
# 46.666666666666664 %

# %%
Data_new
# Out:
#      W    R    AB   2B  3B   HR   BB    SO   SB   RA   ER   ERA  SHO  SV    E
# 1   83  696  5467  277  44  156  439  1264   70  700  653  4.07   12  45   86
# 2   81  669  5439  303  29  141  533  1157   86  640  584  3.67   10  38   79
# 3   76  622  5533  260  27  136  404  1231   68  701  643  3.98    9  37  101
# 4   74  689  5605  289  49  151  455  1259   83  803  746  4.64   12  35   86
# 6   87  764  5567  272  19  212  554  1227   63  698  652  4.03    4  48   93
# 7   81  713  5485  246  20  217  418  1331   44  693  646  4.05   10  43   77
# 9   78  748  5640  294  33  161  478  1148   71  753  694  4.31   10  40   97
# 10  88  751  5511  279  32  172  503  1233  101  733  680  4.24    9  45  119
# 12  85  661  5417  243  21  176  435  1150   52  675  630  3.94   12  46   93
# 13  76  656  5544  262  22  198  478  1336   69  726  677  4.16   12  45   94
# 18  68  655  5480  274  34  145  412  1299   84  737  682  4.28    7  40  116
# ...

# %%
# independent colummn
x=Data_new.iloc[:,:-1]

# %%
# target
y=Data_new.iloc[:,-1]

# %% [markdown]
# Transforming data to remove skewness:

# %%
from sklearn.preprocessing import power_transform

# %%
x=power_transform(x,method='yeo-johnson')

# %%
type(x)
# Out:
# numpy.ndarray

# %%
x
# Out:
# array([[ 4.27345816e-01,  0.00000000e+00,  0.00000000e+00,
#          1.78343382e-01,  1.38682664e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00544254e-01, -1.71162554e-01,
#         -4.39125479e-02,  5.09845206e-02,  5.79366082e-02,
#          5.37037071e-01,  7.40671126e-01],
#        [ 9.99766241e-02,  0.00000000e+00,  0.00000000e+00,
#          1.79122437e+00,  2.40395684e-02,  0.00000000e+00,
#          0.00000000e+00, -1.35711152e+00,  8.39379435e-01,
#         -1.16688061e+00, -1.28059885e+00, -1.17404252e+00,
#         -5.29928606e-02, -8.99569013e-01],
#        [-6.17131494e-01,  0.00000000e+00,  0.00000000e+00,
#         -8.24091390e-01, -1.78636369e-01,  0.00000000e+00,
#          0.00000000e+00, -3.93810298e-01, -2.96642274e-01,
#         -2.60006515e-02, -1.37475972e-01, -2.13856012e-01,
#         -3.58861983e-01, -1.14559759e+00],
#        [-8.66519177e-01,  0.00000000e+00,  0.00000000e+00,
#          9.10905093e-01,  1.79446442e+00,  0.00000000e+00,
# ...

# %%
x.ndim
# Out:
# 2

# %%
from sklearn.preprocessing import StandardScaler
# transform my dataset into a standard normal distribution 
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[ 4.27345816e-01,  0.00000000e+00,  0.00000000e+00,
#          1.78343382e-01,  1.38682664e+00,  0.00000000e+00,
#          0.00000000e+00,  1.00544254e-01, -1.71162554e-01,
#         -4.39125479e-02,  5.09845206e-02,  5.79366082e-02,
#          5.37037071e-01,  7.40671126e-01],
#        [ 9.99766241e-02,  0.00000000e+00,  0.00000000e+00,
#          1.79122437e+00,  2.40395684e-02,  0.00000000e+00,
#          0.00000000e+00, -1.35711152e+00,  8.39379435e-01,
#         -1.16688061e+00, -1.28059885e+00, -1.17404252e+00,
#         -5.29928606e-02, -8.99569013e-01],
#        [-6.17131494e-01,  0.00000000e+00,  0.00000000e+00,
#         -8.24091390e-01, -1.78636369e-01,  0.00000000e+00,
#          0.00000000e+00, -3.93810298e-01, -2.96642274e-01,
#         -2.60006515e-02, -1.37475972e-01, -2.13856012e-01,
#         -3.58861983e-01, -1.14559759e+00],
#        [-8.66519177e-01,  0.00000000e+00,  0.00000000e+00,
#          9.10905093e-01,  1.79446442e+00,  0.00000000e+00,
# ...

# %%
x.mean()
# Out:
# 3.96508223080413e-18

# %%
3.96 * 10**(-18)
# Out:
# 3.9600000000000005e-18

# %%
x.std()
# Out:
# 0.8451542547285166

# %% [markdown]
# since the win has only two classes we will use binary classification model

# %%
Data.W.unique()
# Out:
# array([ 95,  83,  81,  76,  74,  93,  87,  80,  78,  88,  86,  85,  68,
#        100,  98,  97,  64,  90,  71,  67,  63,  92,  84,  79], dtype=int64)

# %%
Data.W.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      95
# 1      83
# 2      81
# 3      76
# 4      74
# 5      93
# 6      87
# 7      81
# 8      80
# 9      78
# 10     88
# 11     86
# 12     85
# 13     76
# 14     68
# 15    100
# 16     98
# 17     97
# 18     68
# 19     64
# 20     90
# 21     83
# 22     71
# 23     67
# 24     63
# 25     92
# 26     84
# 27     79
# 28     74
# 29     68
# Name: W, dtype: int64>

# %%
# over sampling methods 
# undersampling 
# random oversampling
# stacking

# %%
# Homework
# Balance this data and then move ahead

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
lr=LogistcRegression()
from sklearn.metrics import accuracy_score
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16000/3963050360.py in <module>
#       1 from sklearn.model_selection import train_test_split
#       2 from sklearn.linear_model import LogisticRegression
# ----> 3 lr=LogistcRegression()
#       4 from sklearn.metrics import accuracy_score
#
# NameError: name 'LogistcRegression' is not defined

# %%
(100,10)
0 - 50
1 - 50

train_test_split(random_state = 42, test_size=0.2)

# %%
after splitting:
    train --- 0 - 49, 1-31
    test --- 0 - 1, 1-19
    
    selection bais, all the predicitons will be misleading (accuracy as 92%, weigthed avg, macro avg, micro avg)

# %% [markdown]
# Spliting the dataframe:

# %%
lr=LogistcRegression()
for i in range(0,1000):
    x_train,x_test,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    if round(accuracy_score(y_train,pred_train)*100,1)==round(accuracy_score(y_test,pred_test)*100,1):
        print("At random state",i," The model performs very well")
        print("At random_state:-",i)
        print("Training accuracy_score is:-", round(accuracy_score(y_train,pred_train)*100,1))
        print("Testing accuracy_score is:-", round(accuracy_score(y_test,pred_test)*100,1), '\n\n')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16000/2351795063.py in <module>
# ----> 1 lr=LogistcRegression()
#       2 for i in range(0,1000):
#       3     x_train,x_test,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
#       4     lr.fit(x_train,y_train)
#       5     pred_train=lr.predict(x_train)
#
# NameError: name 'LogistcRegression' is not defined
